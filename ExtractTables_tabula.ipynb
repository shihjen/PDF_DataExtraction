# %% [markdown]
# ### tabula-py

# %%
# !pip -qqq install tabula-py

# %%
# import required dependencies
import pandas as pd
import numpy as np
import tabula

# %%
file_path = "C:/Users/65814/OneDrive - National University of Singapore (1)/Tools/PDF_DataExtraction/data/invoice.pdf" 
dfs = tabula.read_pdf(file_path, pages='all', multiple_tables=True, stream=True)
# Out:
# Got stderr: Jun 09, 2024 10:04:52 AM org.apache.pdfbox.pdmodel.PDDocument importPage
# WARNING: inherited resources of source document are not imported to destination page
# Jun 09, 2024 10:04:52 AM org.apache.pdfbox.pdmodel.PDDocument importPage
# WARNING: call importedPage.setResources(page.getResources()) to do this
# Jun 09, 2024 10:04:53 AM org.apache.pdfbox.pdmodel.PDDocument importPage
# WARNING: inherited resources of source document are not imported to destination page
# Jun 09, 2024 10:04:53 AM org.apache.pdfbox.pdmodel.PDDocument importPage
# WARNING: call importedPage.setResources(page.getResources()) to do this

# %%
# check number of tables extracted from the pdf document
print(len(dfs))
# Out:
# 2

# %%
# view tables extracted from the dcoument
for df in dfs:
    display(df)
# Out:
#                                    Description  Quantity  Unit Price  \
# 0   [230428FN-001] One-click sanger sequencing       4.0         4.6
# 1        [230428FN-001] PCR product Sequencing       5.0         4.6
# 2   [230428FN-002] One-click sanger sequencing       3.0         4.6
# 3        [230428FN-002] PCR product Sequencing       3.0         4.6
# 4        [230502FN-004] PCR product Sequencing      78.0         4.6
# 5        [230502FN-015] PCR product Sequencing      10.0         4.6
# 6        [230504FN-001] PCR product Sequencing      20.0         4.6
# 7        [230504FN-004] PCR product Sequencing       2.0         4.6
# 8        [230505FN-001] PCR product Sequencing      30.0         4.6
# 9        [230508FN-001] PCR product Sequencing       8.0         4.6
# 10       [230508FN-002] PCR product Sequencing      30.0         4.6
# 11       [230509FN-001] PCR product Sequencing      40.0         4.6
# 12       [230510FN-001] PCR product Sequencing       8.0         4.6
# ...
